# %% [markdown]
# # CILAB Assignment
# #### Group3_HW6
# #### CNN classifier for the cifar10 dataset
# ##### Arshia Esmail Tehrani
# ##### Ali Babaloo
# ##### Pouya Ebrahimi
# ---

# %% [markdown]
# ## CNN classifier for the cifar10 dataset
# ---

# %% [markdown]
# ### Importing libraries
# ---

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset preperation (Preprocessing)
# ---

# %%
cifar10_data = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10_data.load_data()
assert x_train.shape == (50000, 32, 32, 3)
assert x_test.shape == (10000, 32, 32, 3)
assert y_train.shape == (50000, 1)
assert y_test.shape == (10000, 1)

# %% [markdown]
# #### Dataset scailing
# ---

# %%
def scale_data(train_images, test_images):
    """
    This function takes in the training and test images as loaded in the cell above, and scales them
    so that they have minimum and maximum values equal to 0 and 1 respectively.
    Your function should return a tuple (train_images, test_images) of scaled training and test images.
    """
    train_images = train_images/255.
    test_images = test_images/255.
    
    return (train_images, test_images)

# %%
x_train_s, x_test_s = scale_data(x_train, x_test)
print(f"x_train_s shape:\n{x_train_s.shape}")
print(f"x_test_s shape:\n{x_test_s.shape}")
# Out:
# x_train_s shape:
# (50000, 32, 32, 3)
# x_test_s shape:
# (10000, 32, 32, 3)

# %%
# Add a dummy channel dimension

# x_train_s = x_train_s[..., np.newaxis]
# x_test_s = x_test_s[..., np.newaxis]
# print(f"x_train_s shape:\n{x_train_s.shape}")
# print(f"x_test_s shape:\n{x_test_s.shape}")

# %%
# plotting first few images
for i in range(9):
 # define subplot
 plt.subplot(330 + 1 + i)
 # plot raw pixel data
 plt.imshow(x_train_s[i])
# show the figure
plt.show()

# %% [markdown]
# ### Building the convolutional neural network models
# ---

# %% [markdown]
# #### Model_1 (1 VGG layer)
# ---

# %%
def cnn_get_model_1(input_shape):
    """|
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = tf.keras.Sequential()
    
    # VGG_1
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.2))
    
    # Output
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model

# %% [markdown]
# #### Model_2 (2 VGG layers)
# ---

# %%
def cnn_get_model_2(input_shape):
    """|
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = tf.keras.Sequential()
    
    # VGG_1
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.2))
    
    # VGG_2
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.3))
     
    # Output
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model

# %% [markdown]
# #### Model_3 (3 VGG layers)
# ---

# %%
def cnn_get_model_3(input_shape):
    """|
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = tf.keras.Sequential()
    
    # VGG_1
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.2))
    
    # VGG_2
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.3))
    
    # VGG_3
    model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.4))
    
    # Output
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model

# %%
model_1 = cnn_get_model_1(x_train_s[0].shape)
model_2 = cnn_get_model_2(x_train_s[0].shape)
model_3 = cnn_get_model_3(x_train_s[0].shape)

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 1,060,906
# Trainable params: 1,060,522
# Non-trainable params: 384
# ...

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization_3 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_4 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_6 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 64)          0
#
# ...

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization_8 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_9 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 8, 8, 64)          0
# ...

# %% [markdown]
# #### Compiling the model

# %%
def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with default settings), the cross-entropy loss function and
    accuracy as the only metric. 
    Your function doesn't need to return anything; the model will be compiled in-place.
    """
    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
compile_model(model_1)
compile_model(model_2)
compile_model(model_3)

# %% [markdown]
# #### Training
# ---

# %%
def train_model(model, scaled_train_images, train_labels, batch_size, epochs):
    """
    This function should train the model for # epochs on the scaled_train_images and train_labels. 
    Your function should return the training history, as returned by model.fit.
    """
    history = model.fit(x = scaled_train_images, y = train_labels, batch_size = batch_size, epochs = epochs)
    return history

# %% [markdown]
# ##### Model 1 (1 VGG layer)
# ---

# %%
history_model_1 = train_model(model_1, x_train_s, y_train, batch_size=64, epochs=64)
# history_model_1 = train_model(model_1, x_train_s, y_train, batch_size=64, epochs=10)
# Out:
# Epoch 1/64
# 782/782 [==============================] - 13s 6ms/step - loss: 1.4705 - accuracy: 0.4992
# Epoch 2/64
# 782/782 [==============================] - 4s 6ms/step - loss: 1.0469 - accuracy: 0.6319
# Epoch 3/64
# 782/782 [==============================] - 5s 6ms/step - loss: 0.9325 - accuracy: 0.6721
# Epoch 4/64
# 782/782 [==============================] - 5s 6ms/step - loss: 0.8524 - accuracy: 0.7005
# Epoch 5/64
# 782/782 [==============================] - 5s 6ms/step - loss: 0.7851 - accuracy: 0.7237
# Epoch 6/64
# 782/782 [==============================] - 4s 6ms/step - loss: 0.7250 - accuracy: 0.7452
# Epoch 7/64
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6771 - accuracy: 0.7617
# Epoch 8/64
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6329 - accuracy: 0.7773
# Epoch 9/64
# 782/782 [==============================] - 4s 6ms/step - loss: 0.5883 - accuracy: 0.7927
# Epoch 10/64
# ...

# %% [markdown]
# ###### Plotting the learning curves
# ---

# %%
frame = pd.DataFrame(history_model_1.history)

# %% [markdown]
# ###### Accuracy vs Epochs plot
# ---

# %%
acc_plot = frame.plot(y="accuracy", title="Accuracy vs Epochs", legend=False)
acc_plt = acc_plot.set(xlabel="Epochs", ylabel="Accuracy")

# %% [markdown]
# ###### Loss vs Epochs plot
# ---

# %%
loss_plot = frame.plot(y="loss", title = "Loss vs Epochs",legend=False)
loss_plt = acc_plot.set(xlabel="Epochs", ylabel="Loss")

# %% [markdown]
# ##### Model 2 (2 VGG layers)
# ---

# %%
history_model_2 = train_model(model_2, x_train_s, y_train, batch_size=64, epochs=64)
# history_model_2 = train_model(model_2, x_train_s, y_train, batch_size=64, epochs=10)
# Out:
# Epoch 1/64
# 782/782 [==============================] - 7s 8ms/step - loss: 1.5299 - accuracy: 0.4757
# Epoch 2/64
# 782/782 [==============================] - 6s 8ms/step - loss: 1.0462 - accuracy: 0.6339
# Epoch 3/64
# 782/782 [==============================] - 6s 8ms/step - loss: 0.8961 - accuracy: 0.6892
# Epoch 4/64
# 782/782 [==============================] - 6s 8ms/step - loss: 0.8056 - accuracy: 0.7214
# Epoch 5/64
# 782/782 [==============================] - 6s 8ms/step - loss: 0.7459 - accuracy: 0.7421
# Epoch 6/64
# 782/782 [==============================] - 7s 8ms/step - loss: 0.6896 - accuracy: 0.7610
# Epoch 7/64
# 782/782 [==============================] - 6s 8ms/step - loss: 0.6458 - accuracy: 0.7764
# Epoch 8/64
# 782/782 [==============================] - 6s 8ms/step - loss: 0.6041 - accuracy: 0.7910
# Epoch 9/64
# 782/782 [==============================] - 6s 8ms/step - loss: 0.5828 - accuracy: 0.7972
# Epoch 10/64
# ...

# %% [markdown]
# ###### Plotting the learning curves
# ---

# %%
frame = pd.DataFrame(history_model_2.history)

# %% [markdown]
# ###### Accuracy vs Epochs plot
# ---

# %%
acc_plot = frame.plot(y="accuracy", title="Accuracy vs Epochs", legend=False)
acc_plt = acc_plot.set(xlabel="Epochs", ylabel="Accuracy")

# %% [markdown]
# ###### Loss vs Epochs plot
# ---

# %%
loss_plot = frame.plot(y="loss", title = "Loss vs Epochs",legend=False)
loss_plt = acc_plot.set(xlabel="Epochs", ylabel="Loss")

# %% [markdown]
# ##### Model 3 (3 VGG layers)
# ---

# %%
history_model_3 = train_model(model_3, x_train_s, y_train, batch_size=64, epochs=64)
# history_model_3 = train_model(model_3, x_train_s, y_train, batch_size=64, epochs=10)
# Out:
# Epoch 1/64
# 782/782 [==============================] - 8s 9ms/step - loss: 1.6629 - accuracy: 0.4286
# Epoch 2/64
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1336 - accuracy: 0.5987
# Epoch 3/64
# 782/782 [==============================] - 7s 9ms/step - loss: 0.9367 - accuracy: 0.6688
# Epoch 4/64
# 782/782 [==============================] - 7s 9ms/step - loss: 0.8203 - accuracy: 0.7129
# Epoch 5/64
# 782/782 [==============================] - 7s 9ms/step - loss: 0.7464 - accuracy: 0.7403
# Epoch 6/64
# 782/782 [==============================] - 7s 9ms/step - loss: 0.6797 - accuracy: 0.7655
# Epoch 7/64
# 782/782 [==============================] - 7s 9ms/step - loss: 0.6339 - accuracy: 0.7815
# Epoch 8/64
# 782/782 [==============================] - 7s 9ms/step - loss: 0.5932 - accuracy: 0.7943
# Epoch 9/64
# 782/782 [==============================] - 7s 9ms/step - loss: 0.5544 - accuracy: 0.8105
# Epoch 10/64
# ...

# %% [markdown]
# ###### Plotting the learning curves
# ---

# %%
frame = pd.DataFrame(history_model_3.history)

# %% [markdown]
# ###### Accuracy vs Epochs plot
# ---

# %%
acc_plot = frame.plot(y="accuracy", title="Accuracy vs Epochs", legend=False)
acc_plt = acc_plot.set(xlabel="Epochs", ylabel="Accuracy")

# %% [markdown]
# ###### Loss vs Epochs plot
# ---

# %%
loss_plot = frame.plot(y="loss", title = "Loss vs Epochs",legend=False)
loss_plt = acc_plot.set(xlabel="Epochs", ylabel="Loss")

# %% [markdown]
# #### Model Evaluation
# ---

# %%
def evaluate_model(model, scaled_test_images, test_labels):
    """
    This function should evaluate the model on the scaled_test_images and test_labels. 
    Your function should return a tuple (test_loss, test_accuracy).
    """
    history = model.evaluate(scaled_test_images, test_labels)
    return history

# %% [markdown]
# ##### Model_1 (1 VGG layer)
# ---

# %%
test_loss, test_accuracy = evaluate_model(model_1, x_test_s, y_test)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_accuracy}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1251 - accuracy: 0.7252
# Test loss: 1.1250661611557007
# Test accuracy: 0.7251999974250793

# %%
num_test_images = x_test_s.shape[0]

random_inx = np.random.choice(num_test_images, 4)
random_test_images = x_test_s[random_inx, ...]
random_test_labels = y_test[random_inx, ...]

predictions = model_1.predict(random_test_images)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
    
plt.show()
# Out:
# 1/1 [==============================] - 0s 143ms/step

# %% [markdown]
# ##### Model_2 (2 VGG layers)
# ---

# %%
test_loss, test_accuracy = evaluate_model(model_2, x_test_s, y_test)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_accuracy}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6241 - accuracy: 0.8233
# Test loss: 0.6240770220756531
# Test accuracy: 0.8233000040054321

# %%
num_test_images = x_test_s.shape[0]

random_inx = np.random.choice(num_test_images, 4)
random_test_images = x_test_s[random_inx, ...]
random_test_labels = y_test[random_inx, ...]

predictions = model_2.predict(random_test_images)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
    
plt.show()
# Out:
# 1/1 [==============================] - 0s 141ms/step

# %% [markdown]
# ##### Model_3 (3 VGG layers)
# ---

# %%
test_loss, test_accuracy = evaluate_model(model_3, x_test_s, y_test)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_accuracy}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4617 - accuracy: 0.8688
# Test loss: 0.4617026746273041
# Test accuracy: 0.8687999844551086

# %%
num_test_images = x_test_s.shape[0]

random_inx = np.random.choice(num_test_images, 4)
random_test_images = x_test_s[random_inx, ...]
random_test_labels = y_test[random_inx, ...]

predictions = model_3.predict(random_test_images)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
    
plt.show()
# Out:
# 1/1 [==============================] - 0s 173ms/step

# %% [markdown]
# # ML Second Exercise

# %% [markdown]
# ### Building

# %% [markdown]
# ### Importing libraries
# ---

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset preperation (Preprocessing)
# ---

# %%
cifar10_data = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10_data.load_data()
assert x_train.shape == (50000, 32, 32, 3)
assert x_test.shape == (10000, 32, 32, 3)
assert y_train.shape == (50000, 1)
assert y_test.shape == (10000, 1)

# %% [markdown]
# #### Dataset scailing
# ---

# %%
def scale_data(train_images, test_images):
    """
    This function takes in the training and test images as loaded in the cell above, and scales them
    so that they have minimum and maximum values equal to 0 and 1 respectively.
    Your function should return a tuple (train_images, test_images) of scaled training and test images.
    """
    train_images = train_images/255.
    test_images = test_images/255.
    
    return (train_images, test_images)

# %%
x_train_s, x_test_s = scale_data(x_train, x_test)
print(f"x_train_s shape:\n{x_train_s.shape}")
print(f"x_test_s shape:\n{x_test_s.shape}")
# Out:
# x_train_s shape:
# (50000, 32, 32, 3)
# x_test_s shape:
# (10000, 32, 32, 3)

# %%
# Add a dummy channel dimension

# x_train_s = x_train_s[..., np.newaxis]
# x_test_s = x_test_s[..., np.newaxis]
# print(f"x_train_s shape:\n{x_train_s.shape}")
# print(f"x_test_s shape:\n{x_test_s.shape}")

# %%
# plotting first few images
for i in range(9):
 # define subplot
 plt.subplot(330 + 1 + i)
 # plot raw pixel data
 plt.imshow(x_train_s[i])
# show the figure
plt.show()

# %% [markdown]
# ## CNN Model

# %% [markdown]
# ### Building

# %%
def cnn_get_model_1(input_shape):
    """|
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = tf.keras.Sequential()
    
    # VGG_1
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.2))
    
    # Output
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model

# %%
def cnn_get_model_2(input_shape):
    """|
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = tf.keras.Sequential()
    
    # VGG_1
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='tanh', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='tanh', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.2))
    
    # Output
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='tanh', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(128, activation='tanh', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model

# %%
def cnn_get_model_3(input_shape):
    """|
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = tf.keras.Sequential()
    
    # VGG_1
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='sigmoid', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='sigmoid', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.2))
    
    # Output
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='sigmoid', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(128, activation='sigmoid', kernel_initializer='he_uniform'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model

# %%
model_1_1 = cnn_get_model_1(x_train_s[0].shape)
model_1_2 = cnn_get_model_1(x_train_s[0].shape)
model_1_3 = cnn_get_model_1(x_train_s[0].shape)
model_2 = cnn_get_model_2(x_train_s[0].shape)
model_3 = cnn_get_model_3(x_train_s[0].shape)

# %%
model_1_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
# ...

# %% [markdown]
# ### Compiling

# %%
def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with default settings), the cross-entropy loss function and
    accuracy as the only metric. 
    Your function doesn't need to return anything; the model will be compiled in-place.
    """
    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy', 'mse'])

# %%
compile_model(model_1_1)
compile_model(model_1_2)
compile_model(model_1_3)
compile_model(model_2)
compile_model(model_3)

# %% [markdown]
# ### Training
# ---

# %%
def train_model(model, scaled_train_images, train_labels, batch_size, epochs):
    """
    This function should train the model for # epochs on the scaled_train_images and train_labels. 
    Your function should return the training history, as returned by model.fit.
    """
    history = model.fit(x = scaled_train_images, y = train_labels, batch_size = batch_size, epochs = epochs)
    return history

# %%
# Relu Activation Function
history_model_1_1 = train_model(model_1_1, x_train_s, y_train, batch_size=32, epochs=5)
history_model_1_2 =  train_model(model_1_2, x_train_s, y_train, batch_size=64, epochs=5)
history_model_1_3 =  train_model(model_1_3, x_train_s, y_train, batch_size=128, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 66s 41ms/step - loss: 1.6952 - accuracy: 0.4101 - mse: 27.6361
# Epoch 2/5
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.2376 - accuracy: 0.5615 - mse: 27.6434
# Epoch 3/5
# 1563/1563 [==============================] - 68s 43ms/step - loss: 1.0953 - accuracy: 0.6170 - mse: 27.6493
# Epoch 4/5
# 1563/1563 [==============================] - 66s 42ms/step - loss: 1.0071 - accuracy: 0.6493 - mse: 27.6531
# Epoch 5/5
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.9442 - accuracy: 0.6717 - mse: 27.6558
# Epoch 1/5
# 782/782 [==============================] - 59s 75ms/step - loss: 1.7660 - accuracy: 0.3977 - mse: 27.6369
# Epoch 2/5
# 782/782 [==============================] - 59s 75ms/step - loss: 1.2280 - accuracy: 0.5640 - mse: 27.6436
# Epoch 3/5
# 782/782 [==============================] - 58s 74ms/step - loss: 1.0687 - accuracy: 0.6249 - mse: 27.6501
# Epoch 4/5
# ...

# %%
# Sigmoid and tanh
history_model_2_tanh =  train_model(model_2, x_train_s, y_train, batch_size=128, epochs=5)
history_model_3_sigmoid =  train_model(model_3, x_train_s, y_train, batch_size=128, epochs=5)
# Out:
# Epoch 1/5
# 391/391 [==============================] - 57s 144ms/step - loss: 2.2348 - accuracy: 0.2590 - mse: 27.6299
# Epoch 2/5
# 391/391 [==============================] - 57s 146ms/step - loss: 1.7558 - accuracy: 0.3588 - mse: 27.6263
# Epoch 3/5
# 391/391 [==============================] - 55s 142ms/step - loss: 1.6101 - accuracy: 0.4061 - mse: 27.6283
# Epoch 4/5
# 391/391 [==============================] - 56s 142ms/step - loss: 1.5347 - accuracy: 0.4368 - mse: 27.6305
# Epoch 5/5
# 391/391 [==============================] - 56s 142ms/step - loss: 1.4587 - accuracy: 0.4665 - mse: 27.6333
# Epoch 1/5
# 391/391 [==============================] - 57s 144ms/step - loss: 2.0574 - accuracy: 0.3116 - mse: 27.6338
# Epoch 2/5
# 391/391 [==============================] - 57s 145ms/step - loss: 1.5566 - accuracy: 0.4330 - mse: 27.6330
# Epoch 3/5
# 391/391 [==============================] - 57s 146ms/step - loss: 1.3999 - accuracy: 0.4950 - mse: 27.6366
# Epoch 4/5
# ...

# %% [markdown]
# ###### Plotting the learning curves
# ---

# %%
frame1 = pd.DataFrame(history_model_1_1.history)
frame2 = pd.DataFrame(history_model_1_2.history)
frame3 = pd.DataFrame(history_model_1_3.history)

# %% [markdown]
# ###### Accuracy vs Epochs plot
# ---

# %%
# acc_plot = frame1.plot(y="accuracy", title="Accuracy vs Epochs", legend=False)
# acc_plt = acc_plot.set(xlabel="Epochs", ylabel="Accuracy")

# acc_plot = frame2.plot(y="accuracy", title="Accuracy vs Epochs", legend=False)
# acc_plt = acc_plot.set(xlabel="Epochs", ylabel="Accuracy")

# acc_plot = frame3.plot(y="accuracy", title="Accuracy vs Epochs", legend=False)
# acc_plt = acc_plot.set(xlabel="Epochs", ylabel="Accuracy")

# Run this cell to make the Accuracy vs Epochs plot

fig, axs = plt.subplots(3, 1, figsize=(8, 22))
plt.subplot(311)
plt.plot(history_model_1_1.history['accuracy'])
plt.gca().set_title('"Accuracy vs Epochs -Batch Size 32-"')
plt.xlabel("Epochs")
plt.ylabel("accuracy")

plt.subplot(312)
plt.plot(history_model_1_2.history['accuracy'])
plt.gca().set_title('"Accuracy vs Epochs -Batch Size 64-"')
plt.xlabel("Epochs")
plt.ylabel("accuracy")

plt.subplot(313)
plt.plot(history_model_1_3.history['accuracy'])
plt.gca().set_title('"Accuracy vs Epochs -Batch Size 128-"')
plt.xlabel("Epochs")
plt.ylabel("accuracy")

plt.show()

# %% [markdown]
# ###### Loss vs Epochs plot
# ---

# %%
# loss_plot = frame1.plot(y="loss", title = "Loss vs Epochs",legend=False)
# loss_plt = acc_plot.set(xlabel="Epochs", ylabel="Loss")

# loss_plot = frame2.plot(y="loss", x="epochs",  title = "Loss vs Epochs",legend=False)
# loss_plt = acc_plot.set(xlabel="Epochs", ylabel="Loss")

# loss_plot = frame3.plot(y="loss", title = "Loss vs Epochs",legend=False)
# loss_plt = acc_plot.set(xlabel="Epochs", ylabel="Loss")

fig, axs = plt.subplots(3, 1, figsize=(8, 22))
plt.subplot(311)
plt.plot(history_model_1_1.history['loss'])
plt.gca().set_title('"Loss vs Epochs -batch size 32-"')
plt.xlabel("Epochs")
plt.ylabel("loss")

plt.subplot(312)
plt.plot(history_model_1_2.history['loss'])
plt.gca().set_title('"Loss vs Epochs -batch size 64-"')
plt.xlabel("Epochs")
plt.ylabel("loss")

plt.subplot(313)
plt.plot(history_model_1_3.history['loss'])
plt.gca().set_title('"Loss vs Epochs -batch size 128-"')
plt.xlabel("Epochs")
plt.ylabel("loss")

plt.show()

# %% [markdown]
# ### Sigmoid and tanh functions

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 20))
plt.subplot(321)
plt.plot(history_model_1_1.history['accuracy'])
plt.gca().set_title('"Accuracy vs Epochs -Tanh-"')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.subplot(322)
plt.plot(history_model_1_2.history['accuracy'])
plt.gca().set_title('"accuracy vs Epochs -Sigmoid-"')
plt.xlabel("Epochs")
plt.ylabel("loss")

plt.subplot(323)
plt.plot(history_model_1_3.history['loss'])
plt.gca().set_title('"Loss vs Epochs -Tanh-"')
plt.xlabel("Epochs")
plt.ylabel("loss")

plt.subplot(324)
plt.plot(history_model_1_3.history['loss'])
plt.gca().set_title('"Loss vs Epochs -Sigmoid-"')
plt.xlabel("Epochs")
plt.ylabel("loss")

plt.show()

# %% [markdown]
# #### Model Evaluation
# ---

# %%
def evaluate_model(model, scaled_test_images, test_labels):
    """
    This function should evaluate the model on the scaled_test_images and test_labels. 
    Your function should return a tuple (test_loss, test_accuracy).
    """
    test_loss, test_acc, *is_anything_else_being_returned = model.evaluate(scaled_test_images, test_labels)
    return test_loss, test_acc

# %%
test_loss, test_accuracy = evaluate_model(model_1_1, x_test_s, y_test)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_accuracy}")
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.8665 - accuracy: 0.6968 - mse: 27.6597
# Test loss: 0.8664519786834717
# Test accuracy: 0.6967999935150146

# %%
# Prediction
y_predicted = model_1_1.predict(x=x_test)
# matrix = metrics.confusion_matrix(y_test, y_predicted)
# m = m
# matrix = metrics.confusion_matrix(y_test, y_predicted)
# m = metrics.plot_confusion_matrix()
# Out:
# 313/313 [==============================] - 2s 8ms/step

# %%
# Run this cell to get model predictions on randomly selected test images

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
num_test_images = x_test_s.shape[0]

random_inx = np.random.choice(num_test_images, 4)
random_test_images = x_test_s[random_inx, ...]
random_test_labels = y_test[random_inx, ...]
predictions = model_1_1.predict(random_test_images)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'{class_names[int(label)]}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
    
plt.show()
# Out:
# 1/1 [==============================] - 0s 101ms/step
