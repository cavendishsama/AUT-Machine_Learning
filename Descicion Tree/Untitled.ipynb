# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# # Reading Dataset

# %%
df = pd.read_csv("./assets/nursery.csv")
df
# Out:
#           parents   has_nurs      form children     housing     finance  \
# 0           usual     proper  complete        1  convenient  convenient
# 1           usual     proper  complete        1  convenient  convenient
# 2           usual     proper  complete        1  convenient  convenient
# 3           usual     proper  complete        1  convenient  convenient
# 4           usual     proper  complete        1  convenient  convenient
# ...           ...        ...       ...      ...         ...         ...
# 12955  great_pret  very_crit    foster     more    critical      inconv
# 12956  great_pret  very_crit    foster     more    critical      inconv
# 12957  great_pret  very_crit    foster     more    critical      inconv
# 12958  great_pret  very_crit    foster     more    critical      inconv
# 12959  great_pret  very_crit    foster     more    critical      inconv
#
#               social       health final evaluation
# 0            nonprob  recommended        recommend
# 1            nonprob     priority         priority
# 2            nonprob    not_recom        not_recom
# 3      slightly_prob  recommended        recommend
# 4      slightly_prob     priority         priority
# ...              ...          ...              ...
# 12955  slightly_prob     priority       spec_prior
# 12956  slightly_prob    not_recom        not_recom
# 12957    problematic  recommended       spec_prior
# 12958    problematic     priority       spec_prior
# 12959    problematic    not_recom        not_recom
#
# [12960 rows x 9 columns]

# %% [markdown]
# ## Shuffling

# %%
df = df.sample(frac=1.).reset_index(drop=True)
df
# Out:
#            parents     has_nurs        form children     housing     finance  \
# 0            usual    very_crit    complete        1   less_conv  convenient
# 1       great_pret       proper      foster        3   less_conv  convenient
# 2       great_pret    very_crit   completed        2  convenient  convenient
# 3      pretentious     improper   completed        3    critical      inconv
# 4      pretentious  less_proper      foster        1   less_conv      inconv
# ...            ...          ...         ...      ...         ...         ...
# 12955   great_pret    very_crit   completed        1  convenient      inconv
# 12956   great_pret       proper  incomplete     more   less_conv      inconv
# 12957  pretentious  less_proper  incomplete        3   less_conv  convenient
# 12958  pretentious     improper   completed        3   less_conv      inconv
# 12959   great_pret  less_proper    complete        1   less_conv  convenient
#
#               social       health final evaluation
# 0      slightly_prob  recommended         priority
# 1            nonprob     priority       spec_prior
# 2      slightly_prob  recommended         priority
# 3      slightly_prob    not_recom        not_recom
# 4      slightly_prob    not_recom        not_recom
# ...              ...          ...              ...
# 12955        nonprob     priority       spec_prior
# 12956    problematic    not_recom        not_recom
# 12957        nonprob  recommended         priority
# 12958    problematic     priority       spec_prior
# 12959  slightly_prob    not_recom        not_recom
#
# [12960 rows x 9 columns]

# %% [markdown]
# ## Splitting data into "train" and "test"

# %%
train = df.sample(frac=0.8).reset_index(drop=True)
test = df.drop(index=train.index).reset_index(drop=True)

print(f"dataset shape:\n{df.shape}\n{type(df)}\n")
print(f"train shape:\n{train.shape}\n{type(train)}\n")
print(f"test shape:\n{test.shape}\n{type(test)}")
train
# Out:
# dataset shape:
# (12960, 9)
# <class 'pandas.core.frame.DataFrame'>
#
# train shape:
# (10368, 9)
# <class 'pandas.core.frame.DataFrame'>
#
# test shape:
# (2592, 9)
# <class 'pandas.core.frame.DataFrame'>
#            parents     has_nurs        form children     housing     finance  \
# 0       great_pret    very_crit  incomplete        1    critical  convenient
# 1       great_pret    very_crit  incomplete        2  convenient      inconv
# 2      pretentious     improper   completed        2    critical  convenient
# 3      pretentious  less_proper  incomplete        2    critical      inconv
# 4            usual       proper      foster        2   less_conv      inconv
# ...            ...          ...         ...      ...         ...         ...
# 10363  pretentious       proper    complete        1    critical      inconv
# 10364   great_pret  less_proper   completed        2  convenient  convenient
# 10365  pretentious  less_proper    complete        2  convenient      inconv
# 10366        usual     improper  incomplete     more   less_conv      inconv
# 10367   great_pret     improper      foster        2   less_conv  convenient
#
#               social       health final evaluation
# 0        problematic     priority       spec_prior
# 1        problematic     priority       spec_prior
# 2            nonprob    not_recom        not_recom
# 3            nonprob  recommended         priority
# 4            nonprob    not_recom        not_recom
# ...              ...          ...              ...
# 10363    problematic     priority         priority
# 10364  slightly_prob     priority         priority
# 10365    problematic  recommended         priority
# 10366    problematic     priority         priority
# 10367    problematic  recommended       spec_prior
#
# [10368 rows x 9 columns]

# %% [markdown]
# # Entropy & IG

# %%
# function to calculate the entropy of entire dataset
def base_entropy(dataset):

    target = dataset.iloc[:, -1]
    targets = list(set(target))

    lst = [] # number of each element of targets in target    
    for i in targets:
        lst.append(target.value_counts()[i])
    
    entropy = 0
    _sum = sum(lst)
    for i in range(len(targets)):
        entropy -= (lst[i] / _sum) * (np.log2(lst[i] / _sum))

    return entropy

# function to calculate the entropy of attributes
def entropy(dataset, feature, attribute):
    
    target = dataset.iloc[:, -1]
    targets = list(set(target))
    lst = [0 for i in range(len(targets))]
    flag = 0
    
    for k in targets:
        for i,j in zip(feature, target):
            if i == attribute and j == k:
                lst[flag] += 1
        flag += 1
        
    # Remove all zeros in list - they cus problem in calculating log
    lst[:] = (val for val in lst if val != 0)     
    entropy = 0
    _sum = sum(lst)
    
    for i in range(len(lst)):
        entropy -= (lst[i] / _sum) * (np.log2(lst[i] / _sum))
    
    return entropy

# function that calculates the information gain
def Information_Gain(dataset, feature):
    
    Distinct = list(set(feature))
    Info_Gain = 0
    for i in Distinct:
        t = feature[feature==i].shape[0]  
        Info_Gain = Info_Gain + (t / len(feature)) * entropy(dataset, feature, i)
    Info_Gain = base_entropy(dataset) - Info_Gain
    return Info_Gain

# %%
H_T = base_entropy(df)
print(f"entropy of entire dataset = {H_T}")
print(f"Information Gain of Parent's occupation               = {Information_Gain(df, df['parents'])}")
print(f"Information Gain of Child's nursery                   = {Information_Gain(df, df['has_nurs'])}")
print(f"Information Gain of Form of the family                = {Information_Gain(df, df['form'])}")
print(f"Information Gain of Number of children                = {Information_Gain(df, df['children'])}")
print(f"Information Gain of Housing conditions                = {Information_Gain(df, df['housing'])}")
print(f"Information Gain of Financial standing of the family  = {Information_Gain(df, df['finance'])}")
print(f"Information Gain of Social conditions                 = {Information_Gain(df, df['social'])}")
print(f"Information Gain of Health conditions                 = {Information_Gain(df, df['health'])}")
# Out:
# entropy of entire dataset = 1.7164959001837934
# Information Gain of Parent's occupation               = 0.07293460750309944
# Information Gain of Child's nursery                   = 0.19644928048811572
# Information Gain of Form of the family                = 0.005572591715219843
# Information Gain of Number of children                = 0.011886431475775838
# Information Gain of Housing conditions                = 0.019602025022871894
# Information Gain of Financial standing of the family  = 0.0043331270252005005
# Information Gain of Social conditions                 = 0.022232616894018342
# Information Gain of Health conditions                 = 0.9587749604699762

# %%
def find_most_informative_feature(train_data, label):
    feature_list = train_data.columns.drop(label) 
                                          
    max_info_gain = -1
    max_info_feature = None
    
    for feature in feature_list:  #for each feature in the dataset
        feature_info_gain = Information_Gain(train_data, train_data[feature])
        if max_info_gain < feature_info_gain: #selecting feature name with highest information gain
            max_info_gain = feature_info_gain
            max_info_feature = feature
            
    return max_info_feature

# %%
print(find_most_informative_feature(train, "final evaluation"))
# Out:
# health

# %% [markdown]
# # Generating The Tree

# %%
def ID3(data, attribute, target, max_recursion, recursion=0):
    recursion += 1
    
    _val = data.mode()
    _val.drop(labels=target, axis=1, inplace=True)
    vals = list(data[target])
    
    if (data.empty) | (len(attribute) <= 0):
        return _val
    
    elif vals.count(vals[0]) == len(vals):
        return vals[0]
    
    else:
        #Returns a new decision tree based on the examples given.
        best = find_most_informative_feature(data, target)

        # Create a new decision tree/node with the best attribute and an empty
        # dictionary object--we'll fill that up next.
        tree = {best:{}}
        # Create a new decision tree/sub-node for each of the values in the
        # best attribute field
        for val in list(set(df[best])):
            # depth of the tree
            if recursion >= max_recursion:
                return tree
            
            # Create a subtree for the current value under the "best" field
            example = data.loc[data[best] == val]
            del example[best]
#             example.drop(labels=best, axis=1, inplace=True)
            new_attribute = attribute[:]
            new_attribute.remove(best)
            subtree = ID3(example, new_attribute, target, max_recursion, recursion)

            tree[best][val] = subtree
    
    return tree

# %%
attributes = train.columns.drop('final evaluation').to_list()
label = "final evaluation"

max_recursion = 8 #maximum depth of the tree
# max_recursion = len(attributes)

tree = ID3(train, attributes, label, max_recursion, 0)
test_tree = ID3(test, attributes, label, max_recursion, 0)

# %%
tree
# Out:
# {'health': {'priority': {'has_nurs': {'improper': {'parents': {'usual': 'priority',
#       'pretentious': {'housing': {'critical': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'spec_prior'}},
#           '2': 'spec_prior'}},
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}},
#           'convenient': 'priority'}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': 'priority',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           '2': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}}}}}},
#       'great_pret': {'form': {'incomplete': 'spec_prior',
#         'foster': 'spec_prior',
#         'complete': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           '2': 'spec_prior'}},
#         'completed': 'spec_prior'}}}},
#     'very_crit': {'children': {'more': 'spec_prior',
#       '3': 'spec_prior',
#       '1': {'form': {'incomplete': 'spec_prior',
#         'foster': 'spec_prior',
#         'complete': {'housing': {'critical': 'spec_prior',
#           'convenient': {'finance': {'inconv': 'spec_prior',
#             'convenient': 'priority'}},
#           'less_conv': 'spec_prior'}},
#         'completed': 'spec_prior'}},
#       '2': 'spec_prior'}},
#     'critical': {'parents': {'usual': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': 'priority',
#             '2': 'spec_prior'}},
#           'completed': 'spec_prior'}},
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}},
#           'convenient': 'priority'}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': 'priority',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           '2': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}}}}}},
#       'pretentious': {'children': {'more': 'spec_prior',
#         '3': 'spec_prior',
#         '1': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           'completed': 'spec_prior'}},
#         '2': 'spec_prior'}},
#       'great_pret': {'form': {'incomplete': 'spec_prior',
#         'foster': 'spec_prior',
#         'complete': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           '2': 'spec_prior'}},
#         'completed': 'spec_prior'}}}},
#     'less_proper': {'parents': {'usual': 'priority',
#       'pretentious': 'priority',
#       'great_pret': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': 'priority',
#             '2': 'spec_prior'}},
#           'completed': 'spec_prior'}},
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}},
#           'convenient': 'priority'}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': 'priority',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           '2': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}}}}}}}},
#     'proper': {'parents': {'usual': 'priority',
#       'pretentious': 'priority',
#       'great_pret': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': 'priority',
#             '2': 'spec_prior'}},
#           'completed': 'spec_prior'}},
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}},
#           'convenient': 'priority'}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': 'priority',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           '2': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}}}}}}}}}},
#   'not_recom': 'not_recom',
#   'recommended': {'has_nurs': {'improper': {'parents': {'usual': {'social': {'nonprob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': {'form': {}}}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'slightly_prob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': {'form': {}},
#               '2': {'form': {}}}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'problematic': 'priority'}},
#       'pretentious': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': 'spec_prior'}},
#             'completed': 'spec_prior'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': {'form': {}}}},
#             'convenient': 'priority'}},
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}}}},
#       'great_pret': {'social': {'nonprob': {'children': {'more': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           '3': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           '1': {'form': {'incomplete': 'priority',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': {'housing': {'critical': 'spec_prior',
#               'convenient': 'priority',
#               'less_conv': 'priority'}}}},
#           '2': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': {'form': {}},
#               'convenient': 'priority'}},
#             'less_conv': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}},
#         'slightly_prob': {'housing': {'critical': 'spec_prior',
#           'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': {'form': {}},
#               '2': {'form': {}}}},
#             'convenient': 'priority'}},
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}},
#         'problematic': 'spec_prior'}}}},
#     'very_crit': {'housing': {'critical': {'children': {'more': 'spec_prior',
#         '3': 'spec_prior',
#         '1': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'social': {'nonprob': 'priority',
#             'slightly_prob': 'priority',
#             'problematic': 'spec_prior'}},
#           'completed': 'spec_prior'}},
#         '2': 'spec_prior'}},
#       'convenient': {'social': {'nonprob': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}},
#           'convenient': 'priority'}},
#         'slightly_prob': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}},
#           'convenient': 'priority'}},
#         'problematic': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'completed': 'spec_prior'}},
#           '2': 'spec_prior'}}}},
#       'less_conv': {'children': {'more': 'spec_prior',
#         '3': 'spec_prior',
#         '1': {'social': {'nonprob': {'form': {'incomplete': 'priority',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           'slightly_prob': {'form': {'incomplete': 'priority',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           'problematic': 'spec_prior'}},
#         '2': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'social': {'nonprob': 'priority',
#             'slightly_prob': 'priority',
#             'problematic': 'spec_prior'}},
#           'completed': {'social': {'nonprob': 'priority',
#             'slightly_prob': 'priority',
#             'problematic': 'spec_prior'}}}}}}}},
#     'critical': {'parents': {'usual': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': {'children': {'more': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': 'spec_prior'}},
#             'completed': 'spec_prior'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': {'form': {}}}},
#             'convenient': 'priority'}},
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}}}},
#       'pretentious': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'social': {'nonprob': 'priority',
#               'slightly_prob': 'priority',
#               'problematic': 'spec_prior'}},
#             '2': 'spec_prior'}},
#           'completed': 'spec_prior'}},
#         'convenient': {'social': {'nonprob': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': {'form': {}},
#               '2': {'form': {}}}},
#             'convenient': 'priority'}},
#           'slightly_prob': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': {'form': {}}}},
#             'convenient': 'priority'}},
#           'problematic': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': Empty DataFrame
#               Columns: [finance]
#               Index: []}},
#             '2': 'spec_prior'}}}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'social': {'nonprob': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             'slightly_prob': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             'problematic': 'spec_prior'}},
#           '2': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': {'social': {'nonprob': 'priority',
#               'slightly_prob': 'priority',
#               'problematic': 'spec_prior'}},
#             'completed': {'social': {'nonprob': 'priority',
#               'slightly_prob': 'priority',
#               'problematic': 'spec_prior'}}}}}}}},
#       'great_pret': {'social': {'nonprob': {'housing': {'critical': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'spec_prior'}},
#             '2': 'spec_prior'}},
#           'convenient': {'finance': {'inconv': {'form': {'incomplete': {'children': {}},
#               'foster': 'spec_prior',
#               'complete': {'children': {}},
#               'completed': 'priority'}},
#             'convenient': 'priority'}},
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}},
#         'slightly_prob': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': 'spec_prior'}},
#             'completed': 'spec_prior'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': {'form': {}}}},
#             'convenient': 'priority'}},
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}},
#         'problematic': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'housing': {'critical': 'spec_prior',
#               'convenient': {'finance': {}},
#               'less_conv': 'spec_prior'}},
#             '2': 'spec_prior'}},
#           'completed': 'spec_prior'}}}}}},
#     'less_proper': {'parents': {'usual': {'social': {'nonprob': {'housing': {'critical': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'priority'}},
#             '2': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': {'form': {}}}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': 'very_recom',
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'slightly_prob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': {'form': {}},
#               '2': 'priority'}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'problematic': 'priority'}},
#       'pretentious': {'social': {'nonprob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': {'form': {}},
#               '2': {'form': {}}}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'slightly_prob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': {'form': {}}}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'problematic': 'priority'}},
#       'great_pret': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'children': {'more': 'spec_prior',
#           '3': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           '1': {'form': {'incomplete': {'housing': {'critical': 'spec_prior',
#               'convenient': 'priority',
#               'less_conv': 'priority'}},
#             'foster': {'housing': {'critical': 'spec_prior',
#               'convenient': {'finance': {}},
#               'less_conv': 'spec_prior'}},
#             'complete': 'priority',
#             'completed': {'housing': {'critical': 'spec_prior',
#               'convenient': 'priority',
#               'less_conv': 'priority'}}}},
#           '2': {'housing': {'critical': 'spec_prior',
#             'convenient': {'form': {'incomplete': {'finance': {}},
#               'foster': {'finance': {}},
#               'complete': 'priority',
#               'completed': 'priority'}},
#             'less_conv': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}}}}}},
#     'proper': {'parents': {'usual': {'social': {'nonprob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': {'form': {}}}},
#             'convenient': {'form': {'incomplete': 'very_recom',
#               'foster': 'very_recom',
#               'complete': {'children': {}},
#               'completed': 'very_recom'}}}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'slightly_prob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': {'form': {}},
#               '2': {'form': {}}}},
#             'convenient': {'form': {'incomplete': 'very_recom',
#               'foster': 'very_recom',
#               'complete': {'children': {}},
#               'completed': 'very_recom'}}}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'problematic': 'priority'}},
#       'pretentious': {'social': {'nonprob': {'housing': {'critical': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'priority'}},
#             '2': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': {'form': {}},
#               '2': {'form': {}}}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': Empty DataFrame
#               Columns: [finance]
#               Index: []}}}}}},
#         'slightly_prob': {'housing': {'critical': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': 'priority'}},
#             'completed': 'priority'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': 'priority',
#               '1': 'very_recom',
#               '2': {'form': {}}}},
#             'convenient': 'very_recom'}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'form': {'incomplete': 'very_recom',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             '2': {'form': {'incomplete': 'priority',
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}}}}}},
#         'problematic': 'priority'}},
#       'great_pret': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'housing': {'critical': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': 'priority',
#               '2': 'spec_prior'}},
#             'completed': 'spec_prior'}},
#           'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#               '3': 'spec_prior',
#               '1': {'form': {}},
#               '2': {'form': {}}}},
#             'convenient': 'priority'}},
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': 'priority'}}}}}}}}}}}}}}

# %%
test_tree
# Out:
# {'health': {'priority': {'has_nurs': {'improper': {'parents': {'usual': 'priority',
#       'pretentious': {'housing': {'critical': 'spec_prior',
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': Empty DataFrame
#               Columns: [social]
#               Index: [],
#               'completed': Empty DataFrame
#               Columns: [social]
#               Index: []}},
#             '2': {'form': {'incomplete': Empty DataFrame
#               Columns: [social]
#               Index: [],
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': Empty DataFrame
#               Columns: [social]
#               Index: []}}}},
#           'convenient': 'priority'}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           '2': {'form': {'incomplete': 'spec_prior',
#             'foster': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'complete': 'priority',
#             'completed': 'priority'}}}}}},
#       'great_pret': {'children': {'more': 'spec_prior',
#         '3': 'spec_prior',
#         '1': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': {'housing': {'critical': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           'completed': 'spec_prior'}},
#         '2': 'spec_prior'}}}},
#     'very_crit': {'form': {'incomplete': 'spec_prior',
#       'foster': 'spec_prior',
#       'complete': {'housing': {'critical': 'spec_prior',
#         'convenient': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'finance': {'inconv': 'spec_prior', 'convenient': 'priority'}},
#           '2': 'spec_prior'}},
#         'less_conv': 'spec_prior'}},
#       'completed': 'spec_prior'}},
#     'critical': {'parents': {'usual': {'housing': {'critical': 'spec_prior',
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': 'priority',
#             '2': 'spec_prior'}},
#           'convenient': 'priority'}},
#         'less_conv': {'form': {'incomplete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': 'priority',
#             '2': 'spec_prior'}},
#           'foster': 'spec_prior',
#           'complete': 'priority',
#           'completed': 'spec_prior'}}}},
#       'pretentious': 'spec_prior',
#       'great_pret': 'spec_prior'}},
#     'less_proper': {'parents': {'usual': 'priority',
#       'pretentious': 'priority',
#       'great_pret': {'children': {'more': {'housing': {'critical': 'spec_prior',
#           'convenient': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'spec_prior'}},
#           'less_conv': 'spec_prior'}},
#         '3': 'spec_prior',
#         '1': {'form': {'incomplete': {'housing': {'critical': 'spec_prior',
#             'convenient': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'less_conv': 'priority'}},
#           'foster': {'housing': {'critical': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'convenient': 'priority',
#             'less_conv': 'spec_prior'}},
#           'complete': 'priority',
#           'completed': {'housing': {'critical': 'spec_prior',
#             'convenient': 'priority',
#             'less_conv': Empty DataFrame
#             Columns: [finance, social]
#             Index: []}}}},
#         '2': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': 'priority',
#           'completed': {'housing': {'critical': 'spec_prior',
#             'convenient': 'priority',
#             'less_conv': 'priority'}}}}}}}},
#     'proper': {'parents': {'usual': 'priority',
#       'pretentious': 'priority',
#       'great_pret': {'housing': {'critical': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'form': {'incomplete': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': Empty DataFrame
#             Columns: [finance, social]
#             Index: []}},
#           '2': 'spec_prior'}},
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': Empty DataFrame
#               Columns: [social]
#               Index: [],
#               'completed': 'priority'}},
#             '2': 'spec_prior'}},
#           'convenient': 'priority'}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': 'priority',
#           '2': {'form': {'incomplete': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': Empty DataFrame
#             Columns: [finance, social]
#             Index: []}}}}}}}}}},
#   'not_recom': 'not_recom',
#   'recommended': {'has_nurs': {'improper': {'parents': {'usual': {'social': {'nonprob': {'form': {'incomplete': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': {'housing': {'critical': 'priority',
#               'convenient': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'less_conv': 'very_recom'}},
#             '2': Empty DataFrame
#             Columns: [housing, finance]
#             Index: []}},
#           'foster': 'priority',
#           'complete': {'children': {'more': {'housing': {'critical': 'priority',
#               'convenient': 'very_recom',
#               'less_conv': Empty DataFrame
#               Columns: [finance]
#               Index: []}},
#             '3': {'housing': {'critical': 'priority',
#               'convenient': 'very_recom',
#               'less_conv': 'priority'}},
#             '1': 'very_recom',
#             '2': Empty DataFrame
#             Columns: [housing, finance]
#             Index: []}},
#           'completed': {'children': {'more': 'priority',
#             '3': 'very_recom',
#             '1': Empty DataFrame
#             Columns: [housing, finance]
#             Index: [],
#             '2': Empty DataFrame
#             Columns: [housing, finance]
#             Index: []}}}},
#         'slightly_prob': {'housing': {'critical': 'priority',
#           'convenient': {'children': {'more': 'very_recom',
#             '3': 'very_recom',
#             '1': 'very_recom',
#             '2': {'form': {'incomplete': 'priority',
#               'foster': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'complete': 'very_recom',
#               'completed': Empty DataFrame
#               Columns: [finance]
#               Index: []}}}},
#           'less_conv': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': 'very_recom',
#             '2': Empty DataFrame
#             Columns: [form, finance]
#             Index: []}}}},
#         'problematic': 'priority'}},
#       'pretentious': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'children': {'more': 'spec_prior',
#           '3': {'form': {'incomplete': 'spec_prior',
#             'foster': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'complete': Empty DataFrame
#             Columns: [housing, finance]
#             Index: [],
#             'completed': 'spec_prior'}},
#           '1': {'form': {'incomplete': {'housing': {'critical': 'spec_prior',
#               'convenient': 'priority',
#               'less_conv': 'priority'}},
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': 'priority'}},
#           '2': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'priority'}}}}}},
#       'great_pret': {'children': {'more': 'spec_prior',
#         '3': {'housing': {'critical': 'spec_prior',
#           'convenient': {'social': {'nonprob': {'form': {'incomplete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'foster': 'spec_prior',
#               'complete': 'priority',
#               'completed': Empty DataFrame
#               Columns: [finance]
#               Index: []}},
#             'slightly_prob': 'priority',
#             'problematic': 'spec_prior'}},
#           'less_conv': 'spec_prior'}},
#         '1': {'form': {'incomplete': {'housing': {'critical': 'spec_prior',
#             'convenient': {'social': {'nonprob': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'slightly_prob': 'priority',
#               'problematic': 'spec_prior'}},
#             'less_conv': 'spec_prior'}},
#           'foster': {'housing': {'critical': 'spec_prior',
#             'convenient': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'less_conv': 'spec_prior'}},
#           'complete': 'priority',
#           'completed': {'housing': {'critical': 'spec_prior',
#             'convenient': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'less_conv': 'priority'}}}},
#         '2': {'housing': {'critical': 'spec_prior',
#           'convenient': 'priority',
#           'less_conv': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': 'priority',
#             'completed': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}}}}}}}}}},
#     'very_crit': {'social': {'nonprob': {'children': {'more': {'housing': {'critical': 'spec_prior',
#           'convenient': {'finance': {'inconv': 'spec_prior',
#             'convenient': 'priority'}},
#           'less_conv': 'spec_prior'}},
#         '3': {'housing': {'critical': 'spec_prior',
#           'convenient': {'finance': {'inconv': 'spec_prior',
#             'convenient': 'priority'}},
#           'less_conv': 'spec_prior'}},
#         '1': {'form': {'incomplete': 'priority',
#           'foster': {'parents': {'usual': 'spec_prior',
#             'pretentious': {'housing': {'critical': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'convenient': 'priority',
#               'less_conv': 'spec_prior'}},
#             'great_pret': 'spec_prior'}},
#           'complete': 'priority',
#           'completed': {'housing': {'critical': 'spec_prior',
#             'convenient': Empty DataFrame
#             Columns: [parents, finance]
#             Index: [],
#             'less_conv': 'priority'}}}},
#         '2': {'housing': {'critical': 'spec_prior',
#           'convenient': 'priority',
#           'less_conv': 'priority'}}}},
#       'slightly_prob': {'housing': {'critical': 'spec_prior',
#         'convenient': {'finance': {'inconv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'parents': {'usual': 'spec_prior',
#               'pretentious': Empty DataFrame
#               Columns: [form]
#               Index: [],
#               'great_pret': 'priority'}},
#             '2': 'spec_prior'}},
#           'convenient': 'priority'}},
#         'less_conv': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': 'priority',
#           '2': {'form': {'incomplete': 'spec_prior',
#             'foster': Empty DataFrame
#             Columns: [parents, finance]
#             Index: [],
#             'complete': 'priority',
#             'completed': 'priority'}}}}}},
#       'problematic': {'children': {'more': 'spec_prior',
#         '3': 'spec_prior',
#         '1': {'parents': {'usual': {'form': {'incomplete': 'spec_prior',
#             'foster': 'spec_prior',
#             'complete': {'finance': {'inconv': 'spec_prior',
#               'convenient': 'priority'}},
#             'completed': Empty DataFrame
#             Columns: [housing, finance]
#             Index: []}},
#           'pretentious': 'spec_prior',
#           'great_pret': 'spec_prior'}},
#         '2': 'spec_prior'}}}},
#     'critical': {'parents': {'usual': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'form': {'incomplete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'housing': {'critical': 'spec_prior',
#               'convenient': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'less_conv': 'priority'}},
#             '2': 'spec_prior'}},
#           'foster': {'children': {'more': 'spec_prior',
#             '3': 'priority',
#             '1': Empty DataFrame
#             Columns: [housing, finance]
#             Index: [],
#             '2': 'spec_prior'}},
#           'complete': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': Empty DataFrame
#             Columns: [housing, finance]
#             Index: [],
#             '2': 'priority'}},
#           'completed': 'priority'}}}},
#       'pretentious': {'form': {'incomplete': 'spec_prior',
#         'foster': {'housing': {'critical': 'spec_prior',
#           'convenient': {'children': {'more': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             '3': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             '1': 'spec_prior',
#             '2': 'priority'}},
#           'less_conv': 'spec_prior'}},
#         'complete': {'children': {'more': 'spec_prior',
#           '3': 'spec_prior',
#           '1': {'social': {'nonprob': 'priority',
#             'slightly_prob': 'priority',
#             'problematic': 'spec_prior'}},
#           '2': {'housing': {'critical': 'spec_prior',
#             'convenient': 'priority',
#             'less_conv': 'priority'}}}},
#         'completed': {'children': {'more': 'spec_prior',
#           '3': 'priority',
#           '1': 'spec_prior',
#           '2': 'priority'}}}},
#       'great_pret': {'children': {'more': {'housing': {'critical': 'spec_prior',
#           'convenient': {'form': {'incomplete': {'social': {'nonprob': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'slightly_prob': 'priority',
#               'problematic': 'spec_prior'}},
#             'foster': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'complete': 'spec_prior',
#             'completed': 'spec_prior'}},
#           'less_conv': 'spec_prior'}},
#         '3': {'housing': {'critical': 'spec_prior',
#           'convenient': {'social': {'nonprob': {'form': {'incomplete': 'spec_prior',
#               'foster': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'complete': 'priority',
#               'completed': Empty DataFrame
#               Columns: [finance]
#               Index: []}},
#             'slightly_prob': 'priority',
#             'problematic': 'spec_prior'}},
#           'less_conv': 'spec_prior'}},
#         '1': {'form': {'incomplete': 'priority',
#           'foster': 'spec_prior',
#           'complete': {'social': {'nonprob': 'priority',
#             'slightly_prob': 'priority',
#             'problematic': {'housing': {'critical': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'convenient': 'priority',
#               'less_conv': 'spec_prior'}}}},
#           'completed': {'housing': {'critical': 'spec_prior',
#             'convenient': 'priority',
#             'less_conv': 'priority'}}}},
#         '2': {'form': {'incomplete': 'spec_prior',
#           'foster': 'spec_prior',
#           'complete': 'priority',
#           'completed': {'housing': {'critical': 'spec_prior',
#             'convenient': 'priority',
#             'less_conv': 'priority'}}}}}}}},
#     'less_proper': {'parents': {'usual': {'form': {'incomplete': {'housing': {'critical': 'priority',
#           'convenient': {'social': {'nonprob': 'very_recom',
#             'slightly_prob': {'children': {'more': 'priority',
#               '3': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               '1': 'very_recom',
#               '2': Empty DataFrame
#               Columns: [finance]
#               Index: []}},
#             'problematic': 'priority'}},
#           'less_conv': 'priority'}},
#         'foster': {'housing': {'critical': 'priority',
#           'convenient': {'finance': {'inconv': 'priority',
#             'convenient': 'very_recom'}},
#           'less_conv': 'priority'}},
#         'complete': {'children': {'more': {'finance': {'inconv': 'priority',
#             'convenient': 'very_recom'}},
#           '3': {'housing': {'critical': 'priority',
#             'convenient': {'finance': {'inconv': 'priority',
#               'convenient': 'very_recom'}},
#             'less_conv': 'priority'}},
#           '1': 'very_recom',
#           '2': 'very_recom'}},
#         'completed': {'housing': {'critical': 'priority',
#           'convenient': {'children': {'more': {'finance': {'inconv': 'priority',
#               'convenient': 'very_recom'}},
#             '3': 'priority',
#             '1': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             '2': 'very_recom'}},
#           'less_conv': 'priority'}}}},
#       'pretentious': {'children': {'more': 'priority',
#         '3': {'social': {'nonprob': 'priority',
#           'slightly_prob': {'form': {'incomplete': 'priority',
#             'foster': 'priority',
#             'complete': 'priority',
#             'completed': 'very_recom'}},
#           'problematic': 'priority'}},
#         '1': {'form': {'incomplete': {'housing': {'critical': 'priority',
#             'convenient': 'priority',
#             'less_conv': 'very_recom'}},
#           'foster': 'priority',
#           'complete': {'social': {'nonprob': 'very_recom',
#             'slightly_prob': 'very_recom',
#             'problematic': 'priority'}},
#           'completed': {'housing': {'critical': 'priority',
#             'convenient': 'very_recom',
#             'less_conv': Empty DataFrame
#             Columns: [finance, social]
#             Index: []}}}},
#         '2': {'social': {'nonprob': {'housing': {'critical': 'priority',
#             'convenient': 'very_recom',
#             'less_conv': {'form': {'incomplete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'foster': 'priority',
#               'complete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'completed': 'very_recom'}}}},
#           'slightly_prob': {'form': {'incomplete': Empty DataFrame
#             Columns: [housing, finance]
#             Index: [],
#             'foster': 'priority',
#             'complete': 'very_recom',
#             'completed': 'very_recom'}},
#           'problematic': 'priority'}}}},
#       'great_pret': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'housing': {'critical': 'spec_prior',
#           'convenient': {'finance': {'inconv': 'spec_prior',
#             'convenient': 'priority'}},
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': {'form': {'incomplete': 'priority',
#               'foster': 'spec_prior',
#               'complete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'completed': Empty DataFrame
#               Columns: [finance]
#               Index: []}},
#             '2': {'form': {'incomplete': 'spec_prior',
#               'foster': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'complete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'completed': 'priority'}}}}}}}}}},
#     'proper': {'parents': {'usual': {'housing': {'critical': 'priority',
#         'convenient': {'social': {'nonprob': {'children': {'more': 'priority',
#             '3': 'priority',
#             '1': 'very_recom',
#             '2': 'very_recom'}},
#           'slightly_prob': {'form': {'incomplete': {'finance': {'inconv': 'priority',
#               'convenient': 'very_recom'}},
#             'foster': 'very_recom',
#             'complete': 'very_recom',
#             'completed': 'very_recom'}},
#           'problematic': 'priority'}},
#         'less_conv': {'children': {'more': 'priority',
#           '3': 'priority',
#           '1': {'social': {'nonprob': Empty DataFrame
#             Columns: [form, finance]
#             Index: [],
#             'slightly_prob': {'form': {'incomplete': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'foster': 'priority',
#               'complete': 'very_recom',
#               'completed': 'very_recom'}},
#             'problematic': 'priority'}},
#           '2': {'form': {'incomplete': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'foster': 'priority',
#             'complete': 'very_recom',
#             'completed': {'social': {'nonprob': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'slightly_prob': 'very_recom',
#               'problematic': 'priority'}}}}}}}},
#       'pretentious': {'housing': {'critical': {'children': {'more': 'priority',
#           '3': 'priority',
#           '1': {'form': {'incomplete': 'priority',
#             'foster': Empty DataFrame
#             Columns: [finance, social]
#             Index: [],
#             'complete': {'social': {'nonprob': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               'slightly_prob': 'very_recom',
#               'problematic': 'priority'}},
#             'completed': 'priority'}},
#           '2': 'priority'}},
#         'convenient': {'social': {'nonprob': {'form': {'incomplete': {'children': {'more': 'very_recom',
#               '3': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               '1': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               '2': 'priority'}},
#             'foster': Empty DataFrame
#             Columns: [children, finance]
#             Index: [],
#             'complete': 'very_recom',
#             'completed': 'very_recom'}},
#           'slightly_prob': {'finance': {'inconv': {'children': {'more': 'priority',
#               '3': Empty DataFrame
#               Columns: [form]
#               Index: [],
#               '1': Empty DataFrame
#               Columns: [form]
#               Index: [],
#               '2': 'very_recom'}},
#             'convenient': 'very_recom'}},
#           'problematic': 'priority'}},
#         'less_conv': {'form': {'incomplete': 'priority',
#           'foster': 'priority',
#           'complete': 'priority',
#           'completed': {'social': {'nonprob': 'very_recom',
#             'slightly_prob': {'children': {'more': 'priority',
#               '3': Empty DataFrame
#               Columns: [finance]
#               Index: [],
#               '1': 'very_recom',
#               '2': Empty DataFrame
#               Columns: [finance]
#               Index: []}},
#             'problematic': 'priority'}}}}}},
#       'great_pret': {'social': {'nonprob': 'priority',
#         'slightly_prob': 'priority',
#         'problematic': {'housing': {'critical': 'spec_prior',
#           'convenient': 'priority',
#           'less_conv': {'children': {'more': 'spec_prior',
#             '3': 'spec_prior',
#             '1': 'priority',
#             '2': Empty DataFrame
#             Columns: [form, finance]
#             Index: []}}}}}}}}}}}}

# %%
list(set(train['children']))
# Out:
# ['more', '3', '1', '2']

# %%
test_tree
# Out:
# {'health': {'priority': {'has_nurs': {'improper': {'parents': {}},
#     'very_crit': {'form': {}},
#     'critical': {'parents': {}},
#     'less_proper': {'parents': {}},
#     'proper': {'parents': {}}}},
#   'not_recom': 'not_recom',
#   'recommended': {'has_nurs': {'improper': {'parents': {}},
#     'very_crit': {'social': {}},
#     'critical': {'parents': {}},
#     'less_proper': {'parents': {}},
#     'proper': {'parents': {}}}}}}
